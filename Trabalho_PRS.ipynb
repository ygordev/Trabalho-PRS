# %% [markdown]
# <a href="https://colab.research.google.com/github/ygordev/Trabalho-PRS/blob/main/Trabalho_PRS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf *

# %%
# !wget https://github.com/ygordev/Trabalho-PRS/raw/main/Ygor.wav -v
# !wget https://github.com/ygordev/Trabalho-PRS/raw/main/Mariana.wav -v
# !wget https://github.com/ygordev/Trabalho-PRS/raw/main/Seno-1200.wav -v
# Out:
# --2022-03-13 13:26:02--  https://github.com/ygordev/Trabalho-PRS/raw/main/Ygor.wav
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/ygordev/Trabalho-PRS/main/Ygor.wav [following]
# --2022-03-13 13:26:03--  https://raw.githubusercontent.com/ygordev/Trabalho-PRS/main/Ygor.wav
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2205332 (2.1M) [audio/wav]
# Saving to: ‘Ygor.wav’
#
# Ygor.wav            100%[===================>]   2.10M  --.-KB/s    in 0.01s
#
# 2022-03-13 13:26:03 (171 MB/s) - ‘Ygor.wav’ saved [2205332/2205332]
#
# ...

# %%
# !pip install librosa

# %%
import librosa
import librosa.display

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Criação de uma função para tratamento de variáveis tipo "string" em float.
def converter_str_float(input):
  try:
    return float(input)
  except ValueError:
    return np.nan

# %%
wav_file = r'Mariana.wav'

y, sr = librosa.load(wav_file, sr=22000, mono=True)

f0, voiced_flag, voiced_probs = librosa.pyin(y, fmin=librosa.note_to_hz('C2'), fmax=librosa.note_to_hz('C7'))
times = librosa.times_like(f0)

D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)
fig, ax = plt.subplots(figsize=(12,8))
img = librosa.display.specshow(D, x_axis='time', y_axis='log', ax=ax)
ax.set(title='Estimativa de f0 - pYIN - Mariana')
fig.colorbar(img, ax=ax, format="%+2.f dB")
ax.plot(times, f0, label='f0', color='cyan', linewidth=3)
ax.legend(loc='upper right')

f0_mariana = f0

# %%
tabelaf0_mariana = pd.DataFrame(list(f0_mariana), columns=['Valor'])
tabelaf0_mariana['Valor'] = tabelaf0_mariana['Valor'].apply(converter_str_float)

print("Valor médio de f0 - Mariana: {}".format(tabelaf0_mariana['Valor'].mean()))
# Out:
# Valor médio de f0 - Mariana: 210.7612294584164

# %%
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt

wav_file = r'Ygor.wav'
y, sr = librosa.load(wav_file, sr=22000, mono=True)

f0, voiced_flag, voiced_probs = librosa.pyin(y, fmin=librosa.note_to_hz('C2'), fmax=librosa.note_to_hz('C7'))
times = librosa.times_like(f0)

D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)
fig, ax = plt.subplots(figsize=(12,8))
img = librosa.display.specshow(D, x_axis='time', y_axis='log', ax=ax)
ax.set(title='Estimativa de f0 - pYIN - Ygor')
fig.colorbar(img, ax=ax, format="%+2.f dB")
ax.plot(times, f0, label='f0', color='cyan', linewidth=3)
ax.legend(loc='upper right')

f0_ygor = f0

# %%
tabelaf0_ygor = pd.DataFrame(list(f0_ygor), columns=['Valor'])
tabelaf0_ygor['Valor'] = tabelaf0_ygor['Valor'].apply(converter_str_float)

# %%
print("Valor médio de f0 - Ygor: {}".format(tabelaf0_ygor['Valor'].mean()))
# Out:
# Valor médio de f0 - Ygor: 125.39663052431813

# %%
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt

wav_file = r'Seno-1200.wav'
y, sr = librosa.load(wav_file, sr=22000, mono=True)

f0, voiced_flag, voiced_probs = librosa.pyin(y, fmin=librosa.note_to_hz('C2'), fmax=librosa.note_to_hz('C7'))
times = librosa.times_like(f0)

D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)
fig, ax = plt.subplots(figsize=(12,8))
img = librosa.display.specshow(D, x_axis='time', y_axis='log', ax=ax)
ax.set(title='Estimativa de f0 - pYIN - Ygor')
fig.colorbar(img, ax=ax, format="%+2.f dB")
ax.plot(times, f0, label='f0', color='cyan', linewidth=3)
ax.legend(loc='upper right')

f0_seno = f0

# %%
tabelaf0_seno = pd.DataFrame(list(f0_seno), columns=['Valor'])
tabelaf0_seno['Valor'] = tabelaf0_seno['Valor'].apply(converter_str_float)

# %%
tabelaf0_seno['Valor'].mean()
# Out:
# 1202.115425943863
